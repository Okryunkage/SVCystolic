# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
HIDDEN =32

W1_BITS =8
W2_BITS =8

B1_BITS =16
B2_BITS =32
#fraction bits for fixed point
W1_FRAC =4
W2_FRAC =4

B1_FRAC = W1_FRAC
B2_FRAC = W1_FRAC+W2_FRAC
